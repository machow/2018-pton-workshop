# %%
from utils import search_spotify_album, login_to_spotify, get_spotify_features

# %% [markdown]
# Login to Spotify
# ----------------

# %%
# Use the login_to_spotify function.
sp = login_to_spotify()

# %% [markdown]
# Search for an Album
# ------------------

# %%
# Use the search_spotify_album function.
search_spotify_album("Blue Album")
# Out:
# 1 ----
# name:  Weezer (Deluxe Edition)
# artist:  Weezer
# id:  33CmI2lR8PnQwz6133Mc7l
# 2 ----
# name:  Weezer
# artist:  Weezer
# id:  1xpGyKyV26uPstk1Elgp9Q
# 3 ----
# name:  The Beatles 1967 - 1970 (Remastered)
# artist:  The Beatles
# id:  1cTeNkeINtXiaMLlashAKs
# 4 ----
# name:  Into The Blue Again
# artist:  The Album Leaf
# id:  1nNiEgpGPe2Sxy9fCxlIYW
# 5 ----
# name:  The Blue Album
# artist:  Joey Diaz
# id:  49Lz8u4Ta9t2hmuqMmVU0C
# 6 ----
# name:  Das Nr. 1 Album
# artist:  Modern Talking
# id:  5ZmcYrVf8pD8ETh7jsC2to
# 7 ----
# name:  Blue Album
# artist:  Orbital
# id:  2qmn5ogzGUdDUkBeZfzP5x
# 8 ----
# name:  The Blue Album
# artist:  Mr. Capone-E
# id:  4HLegaAxstadxy6yCBOgL0
# 9 ----
# name:  30 (The New Best of Album)
# artist:  Bad Boys Blue
# id:  2Tva5eNzJWVAbMdayRNxaI
# 10 ----
# name:  The Blue Album
# artist:  Double You
# id:  4FFAbrXcMye0H2wPesW81W

# %%
# Use the get_spotify_features function
feats = get_spotify_features('33CmI2lR8PnQwz6133Mc7l')
feats[0]
# Out:
# {'acousticness': 0.00688,
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3MDmJDJlReM4fTYvgcQvy2',
#  'danceability': 0.656,
#  'duration_ms': 258853,
#  'energy': 0.562,
#  'id': '3MDmJDJlReM4fTYvgcQvy2',
#  'instrumentalness': 1.8e-06,
#  'key': 8,
#  'liveness': 0.0904,
#  'loudness': -6.104,
#  'mode': 1,
#  'name': "Say It Ain't So - Remix",
#  'speechiness': 0.0364,
#  'tempo': 75.843,
#  'time_signature': 4,
#  'track_href': 'https://api.spotify.com/v1/tracks/3MDmJDJlReM4fTYvgcQvy2',
#  'type': 'audio_features',
#  'uri': 'spotify:track:3MDmJDJlReM4fTYvgcQvy2',
#  'valence': 0.4}

# %% [markdown]
# Plotting features
# -----------------

# %%
from utils import plot_avg_features, plot_features

columns = ['danceability', 'energy',
           'acousticness', 
           'instrumentalness',
           'liveness',
           'speechiness',
           'valence']

plot_features(feats[:10], columns, 'Weezer Features')
# Out:
# <ggplot: (-9223372036571096260)>

# %%
plot_avg_features(feats, columns, 'Weezer Features')
# Out:
# <ggplot: (-9223372036558992496)>
